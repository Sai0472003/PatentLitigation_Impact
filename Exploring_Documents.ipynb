# %%
#importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#loading massive, fat ass documents csv
raw_docs = pd.read_csv("/content/gdrive/My Drive/ECO225_Final_Project/PART1/documents.csv")
# Out:
# <ipython-input-2-0feae0f4de83>:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_docs = pd.read_csv("/content/gdrive/My Drive/ECO225_Final_Project/PART1/documents.csv")

# %%
raw_docs
# Out:
#          case_row_id    case_number    case_number_raw district_id  doc_count  \
# 0                1.0  0:79-cv-06704  0:79-cv-06704-JCP        flsd          1
# 1                1.0  0:79-cv-06704  0:79-cv-06704-JCP        flsd          2
# 2                3.0  0:83-cv-06860  0:83-cv-06860-JAG        flsd          1
# 3                3.0  0:83-cv-06860  0:83-cv-06860-JAG        flsd          2
# 4                3.0  0:83-cv-06860  0:83-cv-06860-JAG        flsd          3
# ...              ...            ...                ...         ...        ...
# 9882317          NaN  3:07-cv-00055  3:07-cv-00055-DAK        ohnd        918
# 9882318          NaN  3:07-cv-00055  3:07-cv-00055-DAK        ohnd        919
# 9882319          NaN  3:07-cv-00055  3:07-cv-00055-DAK        ohnd        920
# 9882320          NaN  3:07-cv-00055  3:07-cv-00055-DAK        ohnd        921
# 9882321          NaN  3:07-cv-00055  3:07-cv-00055-DAK        ohnd        922
#
# ...

# %%
raw_docs['long_description'].value_counts().head()
# Out:
# long_description
# Standing Order Regarding Order Governing Proceedings Patent Cases. Signed by Judge Alan D Albright. (Entered: 10/13/2021)                                                                                                                                                                                                                                                                                                                                                                                                                                           116
# ...

# %%
docs = raw_docs[['case_row_id', 'case_number', 'district_id', 'short_description', 'doc_count', 'doc_number', 'long_description']]
docs = docs.set_index('case_row_id').sort_index()

# %%
docs
# Out:
#                case_number district_id short_description  doc_count  \
# case_row_id
# 1.0          0:79-cv-06704        flsd               NaN          1
# 1.0          0:79-cv-06704        flsd               NaN          2
# 3.0          0:83-cv-06860        flsd               NaN          1
# 3.0          0:83-cv-06860        flsd               NaN          2
# 3.0          0:83-cv-06860        flsd               NaN          3
# ...                    ...         ...               ...        ...
# NaN          3:07-cv-00055        ohnd               NaN        918
# NaN          3:07-cv-00055        ohnd               NaN        919
# NaN          3:07-cv-00055        ohnd               NaN        920
# NaN          3:07-cv-00055        ohnd               NaN        921
# NaN          3:07-cv-00055        ohnd               NaN        922
#
#              doc_number                                   long_description
# case_row_id
# ...

# %%
docs['case_number'].nunique()
# Out:
# 90066

# %%
#isolating judgements from documents
judgement_keywords = ['order', 'so ordered', 'judgement', 'judgment']
judgement_mask = docs['long_description'].str.contains('|'.join(judgement_keywords), case=False, na=False)

judgements = docs[judgement_mask.copy()]

# %%
judgements = judgements.drop(['district_id', 'short_description'], axis=1)

# %%
judgements
# Out:
#                case_number  doc_count  doc_number  \
# case_row_id
# 3.0          0:83-cv-06860          5        94.0
# 5.0          0:84-cv-06726          4         1.0
# 14.0         0:92-cv-00398         55        21.0
# 14.0         0:92-cv-00398         45        30.0
# 14.0         0:92-cv-00398         44        31.0
# ...                    ...        ...         ...
# NaN          3:07-cv-00055        907       328.0
# NaN          3:07-cv-00055        909       329.0
# NaN          3:07-cv-00055        911       330.0
# NaN          3:07-cv-00055        916       331.0
# NaN          3:07-cv-00055        921       332.0
#
#                                               long_description
# case_row_id
# 3.0          FINAL JUDGMENT for Kenneth R. Cornwall against...
# 5.0          ORDER DISMISSING cause with prejudice. Court r...
# 14.0         SCHEDULING ORDER setting Joining of parties,am...
# 14.0         MOTION by plaintiff AD-TECK LIMITED, plaintiff...
# ...

# %%
judgements['judgments'] = judgements['long_description']
judgements = judgements.drop(['long_description'], axis=1)

# %%
judgements.to_csv('/content/gdrive/My Drive/ECO225_Final_Project/PART1/judgements.csv')
